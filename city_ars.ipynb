# %%
import sys
sys.path.append('/sessions/kind-jolly-bell/mnt/Prem_Predict')

from prem_pred_model_with_gru import Footy_Predictor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 4
#       1 import sys
#       2 sys.path.append('/sessions/kind-jolly-bell/mnt/Prem_Predict')
# ----> 4 from prem_pred_model_with_gru import Footy_Predictor
#
# ModuleNotFoundError: No module named 'prem_pred_model_with_gru'
