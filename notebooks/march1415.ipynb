# %%
from prem_pred_model import Footy_Predictor

# %%
foot = Footy_Predictor()
# Out:
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:177: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst= True, errors = "raise").dt.date
# ...

# %%
foot.train_model()
# Out:
# [0.3107965  0.27807377 0.41112973]
# Accuracy: 0.4835164835164835
# Log loss: 1.0300138080363257
# Draw class weight: 1.5
# Walk-forward CV log loss: {'xgb': 0.994808556265959, 'rf': 0.9912229443500132, 'et': 0.9925769752080724}
# Pruned feature CV log loss (xgb): 0.994808556265959
# ...

# %%
display(foot.predict_game("Chelsea", "Newcastle United", "2026-03-14", "2025", False, True))
display(foot.predict_game("Manchester United", "Aston Villa", "2026-03-15", "2025", True, True))
foot.predict_game("Liverpool", "Tottenham", "2026-03-15", "2025", True, False)
# Out:
# {'prediction': 'Chelsea wins🥳',
#  'Chance of Chelsea winning': '55.48%',
#  'Chance of a draw': '24.46%',
#  'Chance of Newcastle United winning': '19.31%'}
# {'prediction': 'Manchester United wins🥳',
#  'Chance of Manchester United winning': '46.42%',
#  'Chance of a draw': '25.59%',
#  'Chance of Aston Villa winning': '25.39%'}
# {'prediction': 'Liverpool wins🥳',
#  'Chance of Liverpool winning': '68.27%',
#  'Chance of a draw': '14.62%',
#  'Chance of Tottenham winning': '12.66%'}

# %%
foot.predict_game("Arsenal", "Everton", "2026-03-14", "2025", True, False)
# Out:
# {'prediction': 'Arsenal wins🥳',
#  'Chance of Arsenal winning': '63.06%',
#  'Chance of a draw': '19.45%',
#  'Chance of Everton winning': '13.35%'}

# %%
m = {"yes":True, "no": False}
print(m["yes"])
# Out:
# True
