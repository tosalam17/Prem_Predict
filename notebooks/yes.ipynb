# %%
from prem_pred_model import Footy_Predictor

# %%
foot = Footy_Predictor()
# Out:
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:92: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:92: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:92: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# ...

# %%
s23 = foot.build_match_df("2023")
s23.columns
# Out:
# Index(['Date', 'HomeTeam', 'AwayTeam', 'FTR', 'home_ppda_att', 'home_ppda_def',
#        'home_ppda_allowed_att', 'home_ppda_allowed_def', 'home_rolling_xG_5',
#        'home_rolling_xGA_5', 'home_rolling_npxGD_5', 'home_rolling_npxG_5',
#        'home_rolling_npxGA_5', 'home_rolling_xpts_5',
#        'home_rolling_deep_ratio_5', 'home_rolling_xG_std_5',
#        'home_rolling_xGA_std_5', 'home_rolling_npxGD_std_5', 'away_ppda_att',
#        'away_ppda_def', 'away_ppda_allowed_att', 'away_ppda_allowed_def',
#        'away_rolling_xG_5', 'away_rolling_xGA_5', 'away_rolling_npxGD_5',
#        'away_rolling_npxG_5', 'away_rolling_npxGA_5', 'away_rolling_xpts_5',
#        'away_rolling_deep_ratio_5', 'away_rolling_xG_std_5',
#        'away_rolling_xGA_std_5', 'away_rolling_npxGD_std_5'],
#       dtype='object')
