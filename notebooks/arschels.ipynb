# %%
from prem_pred_model import Footy_Predictor

# %%
foot = Footy_Predictor()
# Out:
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:177: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst= True, errors = "raise").dt.date
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:167: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")

# %%
foot.train_model()
# Out:
# [0.29806003 0.30486239 0.39707758]
# Accuracy: 0.46987951807228917
# Log loss: 1.0126403095384033
# Draw class weight: 2.0
# Walk-forward CV log loss: {'xgb': 1.011520009146083, 'rf': 0.9965119370750719, 'et': 0.9937779139382186}
# Pruned feature CV log loss (xgb): 1.011520009146083
# Feature pruning decisions: [{'batch': 'calendar', 'n_cols': 4, 'baseline_ll': 1.011520009146083, 'trial_ll': 1.0106988424392447, 'accepted': False}, {'batch': 'h2h', 'n_cols': 3, 'baseline_ll': 1.011520009146083, 'trial_ll': 1.012542683933332, 'accepted': False}, {'batch': 'nonlinear_matchup', 'n_cols': 6, 'baseline_ll': 1.011520009146083, 'trial_ll': 1.0106608019565773, 'accepted': False}, {'batch': 'ppda_raw', 'n_cols': 8, 'baseline_ll': 1.011520009146083, 'trial_ll': 1.0399965484165161, 'accepted': False}, {'batch': 'table_gap_delta', 'n_cols': 3, 'baseline_ll': 1.011520009146083, 'trial_ll': 1.0133115750983788, 'accepted': False}, {'batch': 'consistency_cv_delta', 'n_cols': 3, 'baseline_ll': 1.011520009146083, 'trial_ll': 1.0125588738802376, 'accepted': False}]
# Feature count after pruning: 173
# Ensemble weights: {'xgb': 0.3297159372953823, 'rf': 0.3346816536105306, 'et': 0.3356024090940871}
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.52      0.39      0.45        28
#            1       0.50      0.27      0.35        30
#            2       0.43      0.80      0.56        25
#
#     accuracy                           0.47        83
#    macro avg       0.49      0.49      0.45        83
# weighted avg       0.49      0.47      0.45        83
#
#
# Confusion matrix:
#  [[11  6 11]
#  [ 7  8 15]
#  [ 3  2 20]]
# /opt/anaconda3/envs/py311/lib/python3.11/site-packages/sklearn/metrics/_classification.py:310: UserWarning: The y_prob values do not sum to one. Make sure to pass probabilities.
#   warnings.warn(
# {'xgb': XGBClassifier(base_score=None, booster=None, callbacks=None,
#                colsample_bylevel=None, colsample_bynode=None,
#                colsample_bytree=0.7, device=None, early_stopping_rounds=None,
#                enable_categorical=False, eval_metric='mlogloss',
#                feature_types=None, feature_weights=None, gamma=0,
#                grow_policy=None, importance_type=None,
#                interaction_constraints=None, learning_rate=0.01, max_bin=None,
#                max_cat_threshold=None, max_cat_to_onehot=None,
#                max_delta_step=None, max_depth=4, max_leaves=None,
#                min_child_weight=3, missing=nan, monotone_constraints=None,
#                multi_strategy=None, n_estimators=400, n_jobs=None, num_class=3, ...),
#  'rf': RandomForestClassifier(class_weight='balanced_subsample', min_samples_leaf=2,
#                         n_estimators=600, n_jobs=-1, random_state=42),
#  'et': ExtraTreesClassifier(class_weight='balanced_subsample', min_samples_leaf=2,
#                       n_estimators=600, n_jobs=-1, random_state=42)}

# %%
foot.predict_game("Arsenal", "Chelsea", "2026-03-01", "2025", True, True)
# Out:
# {'prediction': 'Arsenal wins🥳',
#  'Chance of Arsenal winning': '49.58%',
#  'Chance of a draw': '29.34%',
#  'Chance of Chelsea winning': '17.72%'}
