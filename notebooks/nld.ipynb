# %%
from prem_pred_model import Footy_Predictor

# %%
foot = Footy_Predictor()
# Out:
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:166: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:166: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   df = df.apply(pd.to_numeric, errors="ignore")
# /Users/tsalami/Desktop/Prem Predict/prem_pred_model.py:176: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Date"] = pd.to_datetime(df["Date"], dayfirst= True, errors = "raise").dt.date
# ...

# %%
foot.train_model()
# Out:
# [0.31586673 0.25593193 0.42820134]
# Accuracy: 0.5217391304347826
# Log loss: 1.0330779180496847
# Walk-forward CV log loss: {'xgb': 0.9861111314890122, 'rf': 0.9910028747629812, 'et': 0.9889520722087677}
# Ensemble weights: {'xgb': 0.3342032448226478, 'rf': 0.33255356764515864, 'et': 0.3332431875321936}
# Draw threshold: 0.3
#
# Classification report:
#                precision    recall  f1-score   support
#
#            0       0.61      0.58      0.59        19
#            1       0.54      0.27      0.36        26
#            2       0.47      0.75      0.58        24
#
#     accuracy                           0.52        69
#    macro avg       0.54      0.53      0.51        69
# weighted avg       0.54      0.52      0.50        69
#
#
# Confusion matrix:
#  [[11  2  6]
#  [ 5  7 14]
#  [ 2  4 18]]
# ...

# %%
foot.predict_game("Manchester City", "Newcastle United", "2026-02-21", "2025", False, True)
# Out:
# {'prediction': 'Manchester City wins🥳',
#  'Chance of Manchester City winning': '63.06%',
#  'Chance of a draw': '20.07%',
#  'Chance of Newcastle United winning': '15.8%'}

# %%
foot.predict_game("Tottenham", "Arsenal", "2026-02-22", "2025", True, True)
# Out:
# {'prediction': 'Arsenal wins🫣',
#  'Chance of Tottenham winning': '16.68%',
#  'Chance of a draw': '19.13%',
#  'Chance of Arsenal winning': '67.37%'}

# %%
foot.predict_game("Leeds", "Manchester City", "2026-02-28", "2025", False, False)
# Out:
# {'prediction': 'Manchester City wins🫣',
#  'Chance of Leeds winning': '24.57%',
#  'Chance of a draw': '24.03%',
#  'Chance of Manchester City winning': '51.4%'}
